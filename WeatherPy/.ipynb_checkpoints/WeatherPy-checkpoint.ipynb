# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 642

# %% [markdown]
# ---

# %%
print(cities)
# Out:
# ['saipan', 'cabedelo', 'coquimbo', 'polyarnyy', 'amahai', 'isaka', 'sioux falls', 'hihifo', 'hermanus', 'vadso', 'kalmunai', 'san patricio', "al bayda'", 'yellowknife', 'papatowai', 'whitehorse', 'hotan', 'georgetown', 'edinburgh of the seven seas', 'amalapuram', 'basoko', 'puerto natales', 'saint-marc', 'nemuro', 'floro', 'tazovsky', 'grytviken', 'ribeira grande', 'rio grande', 'alice springs', 'albany', 'manicore', 'stanley', 'amga', 'blackmans bay', 'bacabal', 'along', 'bethel', 'khandyga', 'iuna', 'port-aux-francais', 'bassila', 'atafu village', 'luderitz', 'dawson creek', 'karlskrona', 'sitka', 'olonkinbyen', 'tiksi', 'constitucion', "podporozh'ye", 'margaret river', 'codrington', 'maceio', 'eastham', 'dauphin', 'punta arenas', 'nan', 'muisne', 'sur', 'nikolayevsk-on-amure', 'mogocha', 'wailua homesteads', 'laikit, laikit ii (dimembe)', 'poyarkovo', 'ushuaia', 'kegen', 'puerto baquerizo moreno', 'gun barrel city', 'utrik', 'adamstown', 'hamilton', 'avarua', 'west island', 'el ba
# ...

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saipan
# Processing Record 2 of Set 1 | cabedelo
# Processing Record 3 of Set 1 | coquimbo
# Processing Record 4 of Set 1 | polyarnyy
# Processing Record 5 of Set 1 | amahai
# Processing Record 6 of Set 1 | isaka
# Processing Record 7 of Set 1 | sioux falls
# Processing Record 8 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | vadso
# Processing Record 11 of Set 1 | kalmunai
# Processing Record 12 of Set 1 | san patricio
# Processing Record 13 of Set 1 | al bayda'
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | papatowai
# Processing Record 16 of Set 1 | whitehorse
# Processing Record 17 of Set 1 | hotan
# Processing Record 18 of Set 1 | georgetown
# Processing Record 19 of Set 1 | edinburgh of the seven seas
# Processing Record 20 of Set 1 | amalapuram
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          620
# Lat           620
# Lng           620
# Max Temp      620
# Humidity      620
# Cloudiness    620
# Wind Speed    620
# Country       620
# Date          620
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     saipan  15.1355  145.7010    298.54        78          20        6.17
# 1   cabedelo  -6.9811  -34.8339    305.52        71          37        5.40
# 2   coquimbo -29.9533  -71.3436    295.00        78          20        6.17
# 3  polyarnyy  69.1989   33.4478    255.50        96         100        2.46
# 4     amahai  -3.3333  128.9167    299.23        86          72        2.84
#
#   Country        Date
# 0      MP  1707501552
# 1      BR  1707501553
# 2      CL  1707501397
# 3      RU  1707501553
# 4      ID  1707501554

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           saipan  15.1355  145.7010    298.54        78          20
# 1         cabedelo  -6.9811  -34.8339    305.52        71          37
# 2         coquimbo -29.9533  -71.3436    295.00        78          20
# 3        polyarnyy  69.1989   33.4478    255.50        96         100
# 4           amahai  -3.3333  128.9167    299.23        86          72
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      MP  1707501552
# 1              5.40      BR  1707501553
# 2              6.17      CL  1707501397
# 3              2.46      RU  1707501553
# 4              2.84      ID  1707501554

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (Current Date)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (Current Date)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")


# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (Current Date)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (Current Date)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, output_file):
#     (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#     regress_values = x_values * slope + intercept
#     line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"

def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, output_file):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"

    # Calculate the coefficient of correlation (r-value)
    correlation_text = f"Correlation (r-value): {round(rvalue, 4)}"

    # Print the correlation text
    print(correlation_text)

    # Create a scatter plot
    plt.scatter(x_values, y_values, marker="o", edgecolors="black")

    # Plot the regression line
    plt.plot(x_values, regress_values, "r-", label=line_eq)

    # Annotate the line equation
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=15, color="red")

    # Incorporate the other graph properties
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()

    # Save the figure
    plt.savefig(output_file)

    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             saipan  15.1355  145.7010    298.54        78          20
# 3          polyarnyy  69.1989   33.4478    255.50        96         100
# 6        sioux falls  43.5500  -96.7003    275.07        74         100
# 8              vadso  70.0744   29.7487    257.24        85          75
# 9           kalmunai   7.4167   81.8167    300.44        63          81
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      MP  1707501552
# 3              2.46      RU  1707501553
# 6              6.69      US  1707501333
# 8              1.54      NO  1707501375
# 9              5.34      LK  1707501556

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        cabedelo  -6.9811  -34.8339    305.52        71          37
# 2        coquimbo -29.9533  -71.3436    295.00        78          20
# 4          amahai  -3.3333  128.9167    299.23        86          72
# 5           isaka  -3.9000   32.9333    294.59        84          91
# 7        hermanus -34.4187   19.2345    291.37        77          25
#
#          Wind Speed Country        Date
# City_ID
# 1              5.40      BR  1707501553
# 2              6.17      CL  1707501397
# 4              2.84      ID  1707501554
# 5              1.87      TZ  1707501554
# 7              5.40      ZA  1707501555

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# nh_lin_reg = plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Max Temp",
#                        "Northern Hemisphere - Max Temp vs. Latitude Linear Regression", "../output_data/Northern_Hemi_Temp_vs_Lat.png")
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], 
                       xlabel="Latitude", ylabel="Max Temp (F)", 
                       title="Northern Hemisphere - Max Temp vs. Latitude Linear Regression",
                       output_file="output_data/Northern_Hemisphere_Max_Temp_vs_Latitude_Linear_Regression.png")
# Out:
# Correlation (r-value): -0.8632

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"],
                       xlabel="Latitude", ylabel="Max Temp (F)",
                       title="Southern Hemisphere - Max Temp vs. Latitude Linear Regression",
                       output_file="output_data/Southern_Hemi_Temp_vs_Lat.png")
# Out:
# Correlation (r-value): 0.5598

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a strong correlation between latitude and temperature in the northern hemisphere but a much weaker correlation in the southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], 
                       xlabel="Latitude", ylabel="Humidity (%)", 
                       title="Northern Hemisphere - Humidity vs. Latitude Linear Regression",
                       output_file="output_data/Northern_Hemi_Humidity_vs_Latitude_Linear_Regression.png")
# Out:
# Correlation (r-value): 0.4681

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], 
                       xlabel="Latitude", ylabel="Humidity (%)", 
                       title="Southern Hemisphere - Humidity vs. Latitude Linear Regression",
                       output_file="output_data/Southern_Hemi_Humidity_vs_Latitude_Linear_Regression.png")
# Out:
# Correlation (r-value): 0.1968

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Similarly, there is a moderate correlation between humidity and temperature in the northern hemisphere and virtually none in the southern hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], 
                       xlabel="Latitude", ylabel="Cloudiness (%)", 
                       title="Northern Hemisphere - Cloudiness vs. Latitude Linear Regression",
                       output_file="output_data/Northern_Hemi_Cloudiness_vs_Latitude_Linear_Regression.png")
# Out:
# Correlation (r-value): 0.3022

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], 
                       xlabel="Latitude", ylabel="Cloudiness (%)", 
                       title="Southern Hemisphere - Cloudiness vs. Latitude Linear Regression",
                       output_file="output_data/Southern_Hemi_Cloudiness_vs_Latitude_Linear_Regression.png")
# Out:
# Correlation (r-value): 0.3296

# %% [markdown]
# **Discussion about the linear relationship:**
#
# In both instances, the relationship between couldiness and temperature is weak.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], 
                       xlabel="Latitude", ylabel="Wind Speed (mph)", 
                       title="Northern Hemisphere - Wind Speed vs. Latitude Linear Regression",
                       output_file="output_data/Northern_Hemi_Wind_Speed_vs_Latitude_Linear_Regression.png")
# Out:
# Correlation (r-value): -0.0363

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], 
                       xlabel="Latitude", ylabel="Wind Speed (mph)", 
                       title="Southern Hemisphere - Wind Speed vs. Latitude Linear Regression",
                       output_file="output_data/Southern_Hemi_Wind_Speed_vs_Latitude_Linear_Regression.png")
# Out:
# Correlation (r-value): -0.3112

# %% [markdown]
# **Discussion about the linear relationship:**
# There is no relationship between wind speed and temperature in the northern hemisphere yet a small negative correlation in the southern hemisphere.
